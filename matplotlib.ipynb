# %% [markdown]
# <a href="https://colab.research.google.com/github/FidelMolday/tupple.py/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

x_values = [1,2,3,4]
y_values = [5,4,6,2]

plt.plot(x_values, y_values)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
